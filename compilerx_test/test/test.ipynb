# %%
! pip install kafka-python
# Out:
# Requirement already satisfied: kafka-python in c:\users\padma dey\anaconda3\lib\site-packages (2.0.2)

# %%
! pip install pymongo kafka-python
# Out:
# Collecting pymongo
#   Downloading pymongo-4.7.2-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: kafka-python in c:\users\padma dey\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\padma dey\anaconda3\lib\site-packages (from pymongo) (2.6.1)
# Downloading pymongo-4.7.2-cp311-cp311-win_amd64.whl (484 kB)
#    ---------------------------------------- 0.0/484.6 kB ? eta -:--:--
#    ------- -------------------------------- 92.2/484.6 kB 2.6 MB/s eta 0:00:01
#    --------------------- ------------------ 256.0/484.6 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 419.8/484.6 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/484.6 kB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/484.6 kB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/484.6 kB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/484.6 kB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/484.6 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 484.6/484.6 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: pymongo
# Successfully installed pymongo-4.7.2

# %%
! pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\padma dey\anaconda3\lib\site-packages (4.7.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\padma dey\anaconda3\lib\site-packages (from pymongo) (2.6.1)

# %%
from kafka import KafkaConsumer
import pandas as pd
import json

# Kafka configuration
bootstrap_servers = 'localhost:9092'
topic_name = 'company'

# Create Kafka consumer
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=bootstrap_servers,
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='my-group',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# Initialize a list to store the messages
messages = []

# Read messages from Kafka topic
print("Reading messages from Kafka topic...")
for message in consumer:
    # Deserialize message value from JSON
    document = message.value
    print("Received message from Kafka:", document)
    
    # Append the document to the list
    messages.append(document)

    # For demonstration purposes, break after reading a few messages
    if len(messages) >= 2:  # Adjust the number as needed
        break

# Convert the list of messages to a pandas DataFrame
df = pd.DataFrame(messages)

# Display the DataFrame
print("\nDataFrame:")
df
# Out:
# Reading messages from Kafka topic...
# Received message from Kafka: {'_id': {'$oid': '5f992ae04bafc79cd69fb84c'}, 'uuid': '7685d6d3-94bb-3c35-9da2-efb17f66644d', 'company': 'Huobi Capital', 'logo': 'https://compilerx-image-storage.s3.us-west-2.amazonaws.com/media/logo/7685d6d3-94bb-3c35-9da2-efb17f66644d.webp', 'contact_email': 'events@huobi.com', 'facebook': 'https://www.facebook.com/huobi.capital.1', 'industry': ['blockchain', 'cryptocurrency', 'financial services', 'venture capital'], 'linkedin': 'https://www.linkedin.com/company/huobi/', 'updated_at': {'$date': '2022-11-25T14:05:41.212Z'}, 'twitter': 'https://twitter.com/huobicapital', 'company_website': 'https://www.huobi.com', 'phone_number': '', 'company_crunchbase_fetched': 1, 'total_contact': 97, 'total_fetched_contact': 97, 'snov_fetched': 0, 'description': 'Huobi Capital is the investment arm of Huobi Group, focusing exclusively on blockchain and crypto assets investment.', 'industry_update': 1, 'domain': 'huobi.com', 'sub_domain_check': 1, 'domain_check': True, 'domain_verified': True, 'redirected_domain': 'huobi.com', 'like_count': 0, 'dislike_count': 1, 'wishlist_count': 0, 'user_count': 8, 'created_at': {'$date': '2022-03-01T08:19:53.750Z'}, 'serial_number': 'CP-AAA0002', 'additional_information': {'has_cb_rank': 1, 'cb_rank_(company)': 112852, 'organization_name_url': 'https://www.crunchbase.com/organization/huobi-bd34', 'headquarters_location': 'Beijing, Beijing, China', 'headquarters_regions': 'Asia-Pacific (APAC)', 'estimated_revenue_range': '', 'operating_status': 'Active', 'founded_date': '2013-09-01', 'founded_date_precision': 'day', 'exit_date': '', 'exit_date_precision': '', 'closed_date': '', 'closed_date_precision': '', 'type': '', 'website': 'https://www.huobi.com/en-us/capital/', 'contact_email': '', 'phone_number': '', 'number_of_articles': 3, 'hub_tags': '', 'full_description': 'Huobi Capital is the investment arm of Huobi Group, focusing exclusively on ventures and projects related to blockchain technology, digital currency, and crypto assets. Blockchain is not only an innovative technology but also a disruptive tool for social transformation.', 'investor_type': 'Corporate Venture Capital', 'investment_stage': 'Venture', 'number_of_portfolio_organizations': 30, 'number_of_investments': 30, 'number_of_lead_investments': 7, 'number_of_exits': 2, 'number_of_exits_(ipo)': 2, 'accelerator_program_type': '', 'accelerator_application_deadline': '', 'accelerator_duration_(in_weeks)': '', 'industry_groups': 'Financial Services, Lending and Investments, Other, Payments, Software', 'number_of_founders': 1, 'founders': 'Leon Li', 'number_of_employees': '1001-5000', 'number_of_funding_rounds': '', 'funding_status': '', 'last_funding_date': '', 'last_funding_amount': '', 'last_funding_amount_currency': '', 'last_funding_amount_currency_(in_usd)': '', 'last_funding_type': '', 'last_equity_funding_amount': '', 'last_equity_funding_amount_currency': '', 'last_equity_funding_amount_currency_(in_usd)': '', 'last_equity_funding_type': '', 'total_equity_funding_amount': '', 'total_equity_funding_amount_currency': '', 'total_equity_funding_amount_currency_(in_usd)': '', 'total_funding_amount': '', 'total_funding_amount_currency': '', 'total_funding_amount_currency_(in_usd)': '', 'top_5_investors': '', 'number_of_lead_investors': '', 'number_of_investors': '', 'number_of_acquisitions': '', 'acquisition_status': '', 'transaction_name': '', 'transaction_name_url': '', 'acquired_by': '', 'acquired_by_url': '', 'announced_date': '', 'announced_date_precision': '', 'price': '', 'price_currency': '', 'price_currency_(in_usd)': '', 'acquisition_type': '', 'acquisition_terms': '', 'ipo_status': 'Private', 'ipo_date': '', 'delisted_date': '', 'delisted_date_precision': '', 'money_raised_at_ipo': '', 'money_raised_at_ipo_currency': '', 'money_raised_at_ipo_currency_(in_usd)': '', 'valuation_at_ipo': '', 'valuation_at_ipo_currency': '', 'valuation_at_ipo_currency_(in_usd)': '', 'stock_symbol': '', 'stock_symbol_url':  ...
# Received message from Kafka: {'_id': {'$oid': '5f992ae34bafc79cd69fb8a8'}, 'uuid': '9d3b2593-101d-3718-ad69-abd6efb3eb91', 'company': 'KuCoin', 'logo': 'https://compilerx-image-storage.s3.us-west-2.amazonaws.com/media/logo/9d3b2593-101d-3718-ad69-abd6efb3eb91.webp', 'contact_email': 'support@kucoin.com', 'facebook': 'https://www.facebook.com/KuCoinOfficial/', 'industry': ['bitcoin', 'blockchain', 'cryptocurrency', 'financial exchanges', 'financial services'], 'linkedin': 'https://www.linkedin.com/company/kucoin/', 'twitter': 'https://twitter.com/kucoincom', 'updated_at': {'$date': '2023-05-10T14:28:00.545Z'}, 'company_website': 'https://www.kucoin.com', 'company_crunchbase_fetched': 1, 'total_contact': 25, 'total_fetched_contact': 16, 'snov_fetched': 0, 'description': 'KuCoin is a global cryptocurrency exchange offering digital assets and providing crypto services to its users.', 'industry_update': 1, 'domain': 'kucoin.com', 'sub_domain_check': 1, 'domain_check': True, 'domain_verified': True, 'redirected_domain': 'kucoin.com', 'phone_number': '', 'like_count': 0, 'dislike_count': 0, 'wishlist_count': 0, 'user_count': 2, 'created_at': {'$date': '2022-03-01T08:19:53.751Z'}, 'serial_number': 'CP-AAA0003', 'additional_information': {'has_cb_rank': 1, 'cb_rank_(company)': 172, 'organization_name_url': 'https://www.crunchbase.com/organization/kucoin', 'headquarters_location': 'Mahé, Beau Vallon, Seychelles', 'headquarters_regions': '', 'estimated_revenue_range': '', 'operating_status': 'Active', 'founded_date': '2017-01-01', 'founded_date_precision': 'year', 'exit_date': '', 'exit_date_precision': '', 'closed_date': '', 'closed_date_precision': '', 'type': 'For Profit', 'website': 'https://www.kucoin.com/?utm_source=crunchbase', 'phone_number': '', 'number_of_articles': 251, 'hub_tags': 'Unicorn', 'full_description': 'KuCoin is a global cryptocurrency exchange for numerous digital assets and cryptocurrencies. Launched in September 2017, KuCoin has grown into one of the most popular crypto exchanges and already has over 8 million registered users across 207 countries and regions around the world.   Known as "People’s Exchange", KuCoin operates in Seychelles, providing users with 24/7 multi-language customer services. Meanwhile, KuCoin has established about 19 local communities in North America, Europe, SEA and other regions, providing users with highly localized services.   As the home of crypto gems, KuCoin has supported over 420 projects with 790+ trading pairs. A number of projects like ICP, BOSON, AERGO, RNDR, and DAO had a primary listing on KuCoin.   In November 2018, KuCoin announced $20 million (USD) round A funding from IDG Capital and Matrix Partners. In 2021, Forbes Advisor named KuCoin as one of the Best Crypto Exchanges.', 'investor_type': '', 'investment_stage': '', 'number_of_portfolio_organizations': 23, 'number_of_investments': 24, 'number_of_lead_investments': 8, 'number_of_exits': 1, 'number_of_exits_(ipo)': 1, 'accelerator_program_type': '', 'accelerator_application_deadline': '', 'accelerator_duration_(in_weeks)': '', 'industry_groups': 'Financial Services, Lending and Investments, Other, Payments, Software', 'number_of_founders': '', 'founders': '', 'number_of_employees': '501-1000', 'number_of_funding_rounds': 3, 'funding_status': '', 'last_funding_date': '2022-07-21', 'last_funding_amount': 10000000, 'last_funding_amount_currency': 'USD', 'last_funding_amount_currency_(in_usd)': 10000000, 'last_funding_type': 'Venture - Series Unknown', 'last_equity_funding_amount': 10000000, 'last_equity_funding_amount_currency': 'USD', 'last_equity_funding_amount_currency_(in_usd)': 10000000, 'last_equity_funding_type': 'Venture - Series Unknown', 'total_equity_funding_amount': 180000000, 'total_equity_funding_amount_currency': 'USD', 'total_equity_funding_amount_currency_(in_usd)': 180000000, 'total_funding_amount': 180000000, 'total_funding_amount_currency': 'USD', 'total_funding_amount_currency_(in_usd)': 180000000, 'top ...
#
# DataFrame:
#                                     _id                                  uuid  \
# 0  {'$oid': '5f992ae04bafc79cd69fb84c'}  7685d6d3-94bb-3c35-9da2-efb17f66644d
# 1  {'$oid': '5f992ae34bafc79cd69fb8a8'}  9d3b2593-101d-3718-ad69-abd6efb3eb91
#
#          company                                               logo  \
# 0  Huobi Capital  https://compilerx-image-storage.s3.us-west-2.a...
# 1         KuCoin  https://compilerx-image-storage.s3.us-west-2.a...
#
#         contact_email                                  facebook  \
# 0    events@huobi.com  https://www.facebook.com/huobi.capital.1
# 1  support@kucoin.com  https://www.facebook.com/KuCoinOfficial/
#
#                                             industry  \
# 0  [blockchain, cryptocurrency, financial service...
# 1  [bitcoin, blockchain, cryptocurrency, financia...
#
#                                    linkedin  \
# 0   https://www.linkedin.com/company/huobi/
# 1  https://www.linkedin.com/company/kucoin/
#
#                               updated_at                           twitter  \
# 0  {'$date': '2022-11-25T14:05:41.212Z'}  https://twitter.com/huobicapital
# 1  {'$date': '2023-05-10T14:28:00.545Z'}     https://twitter.com/kucoincom
#
#    ... linkedin_id_url                                    gpt_description  \
# 0  ...                  Huobi Capital is a blockchain and crypto asset...
# 1  ...                  KuCoin is a secure cryptocurrency exchange wit...
#
#    linkedin_id                            discord  \
# 0        huobi                                NaN
# 1       kucoin  https://discord.gg/kucoinofficial
#
#                                         github  \
# 0                                          NaN
# 1  https://github.com/Kucoin/kucoin-level3-sdk
#
#                               instagram  \
# 0                                   NaN
# 1  https://www.instagram.com/kucoin_th/
#
#                                             keywords  \
# 0                                                NaN
# 1  Crypto Exchange,Cryptocurrency Exchange,Bitcoi...
#
#                                   medium                      reddit  \
# 0                                    NaN                         NaN
# 1  https://www.medium.com/kucoinexchange  http://reddit.com/r/kucoin
#
#                                     youtube
# 0                                       NaN
# 1  https://www.youtube.com/c/KuCoinExchange
#
# [2 rows x 40 columns]
